# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv('data/analyze_data/basic_properties.csv',index_col=0)
b = pd.read_csv('data/analyze_data/graphomaly_feature.csv',index_col=0)
c = pd.read_csv('data/analyze_data/nodevec.csv',index_col=0)

# %%
labels = a['label']
a.drop(columns=['label'],inplace=True)

b.drop(columns=b.columns[:6],inplace=True)
col_list = ['f_egored_nr_trans_in', 'f_egored_nr_trans_out',]
b.drop(columns=col_list,inplace=True)

# %%
X_1 = pd.merge(left=a,right=b,left_index=True,right_index=True)

# %%
X_1
# Out:
#        in_degree  out_degree  in_strength_total  out_strength_total  label  \
# 0            133        5555            3855777           226032156      0
# 1              1           0              15880                   0      0
# 2              3           0              29332                   0      0
# 3            188          28            6322805              690294      0
# 4              6           0             171353                   0      0
# ...          ...         ...                ...                 ...    ...
# 49995          0           1                  0                2351      0
# 49996          0           1                  0                 615      0
# 49997          0           1                  0                 396      0
# 49998          7           7             563542              591317      0
# 49999          0           1                  0                 192      0
#
#        f_ego_nr_nodes  f_ego_nr_edges  f_egored_degree_in  \
# ...
